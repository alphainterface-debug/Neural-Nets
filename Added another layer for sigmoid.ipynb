# %% [markdown]
# <a href="https://colab.research.google.com/github/alphainterface-debug/Neural-Nets/blob/main/Added%20another%20layer%20for%20sigmoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras as ks
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
print(tf.__version__)
# Out:
# 2.5.0

# %%
dfw = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv")

# %%
dfw.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...

# %%
dfr = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv")

# %%
dfr.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5

# %%
dfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                   --------------  -----
#  0   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"  4898 non-null   object
# dtypes: object(1)
# memory usage: 38.4+ KB

# %%
dfw.describe()
# Out:
#        fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# count                                                4898
# unique                                               3961
# top     7.3;0.19;0.27;13.9;0.057;45;155;0.99807;2.94;0...
# freq                                                    8

# %%
dfw.columns
# Out:
# Index(['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'], dtype='object')

# %%
str1 = 'fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'

# %%
str1
# Out:
# 'fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'

# %%
dfw1 = dfw[str1].str.split(';',expand=True)

# %%
dfw.columns
# Out:
# Index(['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'], dtype='object')

# %%
dfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                   --------------  -----
#  0   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"  4898 non-null   object
# dtypes: object(1)
# memory usage: 38.4+ KB

# %%
dfw1.head()
# Out:
#   fixed acidity volatile acidity citric acid  ... sulphates alcohol quality
# 0             7             0.27        0.36  ...      0.45     8.8       6
# 1           6.3              0.3        0.34  ...      0.49     9.5       6
# 2           8.1             0.28         0.4  ...      0.44    10.1       6
# 3           7.2             0.23        0.32  ...       0.4     9.9       6
# 4           7.2             0.23        0.32  ...       0.4     9.9       6
#
# [5 rows x 12 columns]

# %%
dfw1 = dfw1.rename(columns={0:'fixed acidity',1:'volatile acidity',2:"citric acid",3:"residual sugar",4:"chlorides",5:"free sulfur dioxide",6:"total sulfur dioxide",7:"density",8:"pH",9:"sulphates",10:"alcohol",11:"quality"})

# %%
dfr1 = dfr[str1].str.split(';',expand=True)

# %%
dfr1 = dfr1.rename({0:'fixed acidity',1:'volatile acidity',2:"citric acid",3:"residual sugar",4:"chlorides",5:"free sulfur dioxide",6:"total sulfur dioxide",7:"density",8:"pH",9:"sulphates",10:"alcohol",11:"quality"},axis='columns')

# %%
dfr1['type'] = 1
dfw1['type'] = 0

# %%
dfw1.head().transpose()
# Out:
#                           0      1       2       3       4
# fixed acidity             7    6.3     8.1     7.2     7.2
# volatile acidity       0.27    0.3    0.28    0.23    0.23
# citric acid            0.36   0.34     0.4    0.32    0.32
# residual sugar         20.7    1.6     6.9     8.5     8.5
# chlorides             0.045  0.049    0.05   0.058   0.058
# free sulfur dioxide      45     14      30      47      47
# total sulfur dioxide    170    132      97     186     186
# density               1.001  0.994  0.9951  0.9956  0.9956
# pH                        3    3.3    3.26    3.19    3.19
# sulphates              0.45   0.49    0.44     0.4     0.4
# alcohol                 8.8    9.5    10.1     9.9     9.9
# quality                   6      6       6       6       6
# type                      0      0       0       0       0

# %%
dfr1 = dfr1.append(dfw1,ignore_index=True)

# %%
dfr1.head().transpose()
# Out:
#                            0       1      2      3       4
# fixed acidity            7.4     7.8    7.8   11.2     7.4
# volatile acidity         0.7    0.88   0.76   0.28     0.7
# citric acid                0       0   0.04   0.56       0
# residual sugar           1.9     2.6    2.3    1.9     1.9
# chlorides              0.076   0.098  0.092  0.075   0.076
# free sulfur dioxide       11      25     15     17      11
# total sulfur dioxide      34      67     54     60      34
# density               0.9978  0.9968  0.997  0.998  0.9978
# pH                      3.51     3.2   3.26   3.16    3.51
# sulphates               0.56    0.68   0.65   0.58    0.56
# alcohol                  9.4     9.8    9.8    9.8     9.4
# quality                    5       5      5      6       5
# type                       1       1      1      1       1

# %%
pd.isnull(dfr1).count()
# Out:
# fixed acidity           6497
# volatile acidity        6497
# citric acid             6497
# residual sugar          6497
# chlorides               6497
# free sulfur dioxide     6497
# total sulfur dioxide    6497
# density                 6497
# pH                      6497
# sulphates               6497
# alcohol                 6497
# quality                 6497
# type                    6497
# dtype: int64

# %%
dfr1['type'].unique()
# Out:
# array([1, 0])

# %%
dfr1['fixed acidity'].value_counts()
# Out:
# 6.8     354
# 6.6     327
# 6.4     305
# 7.0     282
# 6.9     279
#        ...
# 13.8      1
# 3.8       1
# 13.5      1
# 13.4      1
# 12.1      1
# Name: fixed acidity, Length: 106, dtype: int64

# %%
import seaborn as sns

# %%
dfr1.head()
# Out:
#   fixed acidity volatile acidity citric acid  ... alcohol quality type
# 0           7.4              0.7           0  ...     9.4       5    1
# 1           7.8             0.88           0  ...     9.8       5    1
# 2           7.8             0.76        0.04  ...     9.8       5    1
# 3          11.2             0.28        0.56  ...     9.8       6    1
# 4           7.4              0.7           0  ...     9.4       5    1
#
# [5 rows x 13 columns]

# %%
dfr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   float64
#  12  type                  6497 non-null   float64
# dtypes: float64(13)
# memory usage: 660.0 KB

# %%
dfr1= dfr1.astype('float64')

# %%
sns.pairplot(dfr1,diag_kind='kde',hue='type')

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import relu

# %%
NNmodel = Sequential()

# %%
NNmodel.add(Dense(8,activation='relu',input_shape=(12,)))

# %%
NNmodel.add(Dense(1,activation='sigmoid'))

# %%
NNmodel.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['binary_accuracy'])

# %%
from sklearn.model_selection import train_test_split

# %%
X = dfr1.iloc[:,:-1]
y = pd.DataFrame(dfr1.iloc[:,-1])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
y.columns
# Out:
# Index(['type'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
s1 = StandardScaler()

# %%
scaler = s1.fit(X_train)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
epoch = 20
batchsize = 250
history = NNmodel.fit(X_train,y_train,epochs=epoch,batch_size=batchsize,validation_split=0.3)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5172 - binary_accuracy: 0.8972 - val_loss: 0.3733 - val_binary_accuracy: 0.9092
# Epoch 2/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4631 - binary_accuracy: 0.9038 - val_loss: 0.3266 - val_binary_accuracy: 0.9245
# Epoch 3/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4253 - binary_accuracy: 0.9095 - val_loss: 0.2979 - val_binary_accuracy: 0.9260
# Epoch 4/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3828 - binary_accuracy: 0.9173 - val_loss: 0.2683 - val_binary_accuracy: 0.9333
# Epoch 5/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3528 - binary_accuracy: 0.9192 - val_loss: 0.2476 - val_binary_accuracy: 0.9355
# Epoch 6/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3264 - binary_accuracy: 0.9202 - val_loss: 0.2216 - val_binary_accuracy: 0.9451
# Epoch 7/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2945 - binary_accuracy: 0.9290 - val_loss: 0.2064 - val_binary_accuracy: 0.9480
# Epoch 8/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2720 - binary_accuracy: 0.9309 - val_loss: 0.1954 - val_binary_accuracy: 0.9480
# Epoch 9/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2533 - binary_accuracy: 0.9349 - val_loss: 0.1824 - val_binary_accuracy: 0.9487
# Epoch 10/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2351 - binary_accuracy: 0.9384 - val_loss: 0.1730 - val_binary_accuracy: 0.9495
# Epoch 11/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2209 - binary_accuracy: 0.9393 - val_loss: 0.1659 - val_binary_accuracy: 0.9495
# Epoch 12/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2092 - binary_accuracy: 0.9400 - val_loss: 0.1628 - val_binary_accuracy: 0.9487
# Epoch 13/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1999 - binary_accuracy: 0.9409 - val_loss: 0.1599 - val_binary_accuracy: 0.9495
# Epoch 14/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1893 - binary_accuracy: 0.9428 - val_loss: 0.1590 - val_binary_accuracy: 0.9516
# Epoch 15/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1840 - binary_accuracy: 0.9441 - val_loss: 0.1613 - val_binary_accuracy: 0.9509
# Epoch 16/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1786 - binary_accuracy: 0.9437 - val_loss: 0.1578 - val_binary_accuracy: 0.9502
# Epoch 17/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1757 - binary_accuracy: 0.9463 - val_loss: 0.1602 - val_binary_accuracy: 0.9495
# Epoch 18/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1738 - binary_accuracy: 0.9459 - val_loss: 0.1570 - val_binary_accuracy: 0.9487
# Epoch 19/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1734 - binary_accuracy: 0.9478 - val_loss: 0.1614 - val_binary_accuracy: 0.9502
# Epoch 20/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1699 - binary_accuracy: 0.9491 - val_loss: 0.1571 - val_binary_accuracy: 0.9473

# %%
loss,accuracy = NNmodel.evaluate(X_test,y_test)
# Out:
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4687 - binary_accuracy: 0.8200

# %%
y
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 6492    0.0
# 6493    0.0
# 6494    0.0
# 6495    0.0
# 6496    0.0
# Name: type, Length: 6497, dtype: float64

# %%
df1 = pd.DataFrame(history.history['binary_accuracy'])
df2 = pd.DataFrame(history.history['val_binary_accuracy'])
forbx = pd.concat([df1,df2],axis = 1)
forbx.boxplot()
